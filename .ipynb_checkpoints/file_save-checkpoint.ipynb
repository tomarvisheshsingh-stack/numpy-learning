# %%
import numpy as np

# %%
n = np.array([[1,2,3],[4,5,6]])
np.savetxt("mar23.txt", n, delimiter = ': ', fmt='%d', header = "first file", footer = "end of code", comments = "# ")

# %%
b = np.array([[1,2,3],[4,5,6]])
print(b)
np.save('mfile', b)
print('data saved')
# Out:
# [[1 2 3]
#  [4 5 6]]
# data saved

# %%
k = np.load('mfile.npy')
print(k)
# Out:
# [[1 2 3]
#  [4 5 6]]
